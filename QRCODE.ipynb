# %%
pip install pyqrcode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 307 kB/s
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36247 sha256=a389af6d8fe89eb2d5f30fcdac74c70a0ae2d4b7ca5f6f29087277853a79f85f
#   Stored in directory: /root/.cache/pip/wheels/aa/14/ad/f09824edf35fdc5fd8acc01b60ff57f858f212a2d5c41dddd2
# Successfully built pyqrcode
# ...

# %%
pip install pypng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 58 kB 2.8 MB/s
# ...

# %%
import pyqrcode
import png
from pyqrcode import QRCode

s = "First;Address:123 Some ;Email:some_name@some_ip.com; Phone No:+11800123123; Order date:19052022;;"

url = pyqrcode.create(s)

url.png('myqr.png', scale = 6)
